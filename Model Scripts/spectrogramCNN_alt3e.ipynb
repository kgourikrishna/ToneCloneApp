# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/Dataset
# !cp -r /content/drive/MyDrive/W210/Dataset/final_real.csv /content/Dataset/final_real.csv
# !cp -r /content/drive/MyDrive/W210/Dataset/final_real.h5 /content/Dataset/final_real.h5
# !cp -r /content/drive/MyDrive/W210/Dataset/final_test.csv /content/Dataset/final_test.csv
# !cp -r /content/drive/MyDrive/W210/Dataset/final_test.h5 /content/Dataset/final_test.h5
# !cp -r /content/drive/MyDrive/W210/Dataset/final_train.csv /content/Dataset/final_train.csv
# !cp -r /content/drive/MyDrive/W210/Dataset/final_train.h5 /content/Dataset/final_train.h5
# !cp -r /content/drive/MyDrive/W210/Dataset/final_validate.csv /content/Dataset/final_validate.csv
# !cp -r /content/drive/MyDrive/W210/Dataset/final_validate.h5 /content/Dataset/final_validate.h5

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import h5py
import pandas as pd
from sklearn.metrics import classification_report
import torchaudio.transforms as T
import random
import warnings

warnings.filterwarnings("ignore", message="Downcasting object dtype arrays on .fillna")

class SpectrogramDataset(Dataset):
    """
    Custom dataset for spectrogram data.

    When the Spectrogram dataset is used to create a dataloader object, the
    dataloader consists of batches of spectrograms and their corresponding labels.
    Here is info on the shape of the spectrogram and label objects in each batch:

    Spectrogram Tensor Dimensions in Batch - (32, 1, 128, 626)
        Batch Size: 32
        Channels: 1 - Think of it as a grayscale image, rather than RGB
        Mel Bands (Height): 128 - 128 Mel filter banks (typical for Mel spectrograms)
        Time Steps (Width): 626 - Number of frames

    Label Tensor Dimensions in Batch - (32, 13)
        Batch Size: 32
        Number of Labels: 13 - Multi-hot encoded vector of the 13 effects (includes clean). This
            would increase if we added additional effects.
    """

    def __init__(self, hdf5_file, csv_file, augment=True, noise_level=0.03,
                 pitch_shift_range=(-0.5, 0.5), time_shift_range=(-5, 5), volume_change_range=(-5, 5)):
        """
        Args:
            hdf5_file (str): Path to the HDF5 file containing spectrograms.
            csv_file (str): Path to CSV file with labels.
            augment (bool): Whether to apply data augmentation.
            noise_level (float): Standard deviation of Gaussian noise to add.
            pitch_shift_range (tuple): Min/max semitones for pitch shifting.
        """
        self.hdf5_file_path = hdf5_file
        self.labels = pd.read_csv(csv_file)
        self.labels = self.labels.iloc[:, [0] + list(range(-12, 0))]
        self.label_map = self.labels.columns[1:].tolist()  # Get effect label names
        self.hdf5_file = None  # Open HDF5 file once per worker

        self.augment = augment
        self.noise_level = noise_level
        self.pitch_shift_range = pitch_shift_range
        self.time_shift_range = time_shift_range
        self.volume_change_range = volume_change_range

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        # Open HDF5 file per worker to avoid threading issues
        if self.hdf5_file is None:
            self.hdf5_file = h5py.File(self.hdf5_file_path, "r", swmr=True)

        # Retrieve spectrogram
        key = self.labels.iloc[idx]['key']
        spectrogram = torch.tensor(self.hdf5_file[key][()], dtype=torch.float32).unsqueeze(0)

        # Retrieve labels
        label_values = self.labels.iloc[idx][1:].fillna(0).astype(float).values
        label = torch.tensor(label_values, dtype=torch.float32)

        # Data augmentation
        if self.augment:
            spectrogram = self.add_noise(spectrogram)
            spectrogram = self.pitch_shift(spectrogram)
            spectrogram = self.time_shift(spectrogram)
            spectrogram = self.volume_change(spectrogram)

        return spectrogram, label

    def add_noise(self, spectrogram):
        """Adds Gaussian noise where noise level is randomly chosen between 0 and self.noise_level."""
        if random.random() < 0.5:
            return spectrogram
        noise_level = random.uniform(0, self.noise_level)  # Random noise per sample
        noise = torch.randn_like(spectrogram) * noise_level  # Scale noise
        return spectrogram + noise

    def pitch_shift(self, spectrogram):
        """Shifts spectrogram frequency bins using torch.roll() with zero padding."""
        if random.random() < 0.5:
            return spectrogram
        semitone_shift = random.uniform(*self.pitch_shift_range)  # Random shift between min/max
        shift_bins = int(semitone_shift / 12 * spectrogram.shape[-2])  # Convert semitone shift to frequency bins

        # Apply frequency bin shift using torch.roll() with zero-padding
        shifted = torch.roll(spectrogram, shifts=shift_bins, dims=-2)  # Shift along frequency axis

        if shift_bins > 0:  # Shift up (higher pitch)
            shifted[..., :shift_bins, :] = 0  # Zero-pad low frequencies
        elif shift_bins < 0:  # Shift down (lower pitch)
            shifted[..., shift_bins:, :] = 0  # Zero-pad high frequencies

        return shifted

    def time_shift(self, spectrogram):
        """Shifts spectrogram time steps using torch.roll() with zero padding."""
        if random.random() < 0.5:
            return spectrogram
        shift_frames = random.randint(*self.time_shift_range)  # Random shift between min/max
        shifted = torch.roll(spectrogram, shifts=shift_frames, dims=-1)
        if shift_frames > 0:
            shifted[..., :shift_frames, :] = 0
        elif shift_frames < 0:
            shifted[..., shift_frames:, :] = 0
        return shifted

    def volume_change(self, spectrogram):
        if random.random() < 0.5:
            return spectrogram
        volume_change = random.uniform(*self.volume_change_range)
        spectrogram = spectrogram * (1 + volume_change / 100)
        return spectrogram

    def __del__(self):
        if self.hdf5_file is not None:
            self.hdf5_file.close()

# %%
class spectrogramCNN(nn.Module):
    def __init__(self, num_classes):
        super(spectrogramCNN, self).__init__()

        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)
        self.bn4 = nn.BatchNorm2d(256)
        self.conv5 = nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1)
        self.bn5 = nn.BatchNorm2d(512)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))

        self.fc1 = nn.Linear(512, 256)
        self.dropout = nn.Dropout(0.1)
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x):
        x = self.pool(self.bn1(torch.relu(self.conv1(x))))
        x = self.pool(self.bn2(torch.relu(self.conv2(x))))
        x = self.pool(self.bn3(torch.relu(self.conv3(x))))
        x = self.pool(self.bn4(torch.relu(self.conv4(x))))
        x = self.pool(self.bn5(torch.relu(self.conv5(x))))
        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)

        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
# Initialize dataset from HD5F and csv file

h5_train_path = '/content/Dataset/final_train.h5'
csv_train_path = '/content/Dataset/final_train.csv'

h5_val_path = '/content/Dataset/final_validate.h5'
csv_val_path = '/content/Dataset/final_validate.csv'

h5_test_path = '/content/Dataset/final_test.h5'
csv_test_path = '/content/Dataset/final_test.csv'

h5_real_path = '/content/Dataset/final_real.h5'
csv_real_path = '/content/Dataset/final_real.csv'

model_save_path = "/content/drive/MyDrive/W210/Models/last_model.mod"
model_load_path = "/content/drive/MyDrive/W210/Models/last_model.mod"

train_dataset = SpectrogramDataset(h5_train_path, csv_train_path)
val_dataset = SpectrogramDataset(h5_val_path, csv_val_path)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=12, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=6, pin_memory=True)

num_classes = len(train_dataset.label_map)

model = spectrogramCNN(num_classes).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.398)  # 0.0001 → 0.00001 over 5 epochs
#optimizer = torch.optim.SGD(model.parameters(), lr=0.0005, momentum=0.9, weight_decay=1e-4)

# Training loop
num_epochs = 5
print_freq = 10
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    for batch_idx, (spectrograms, labels) in enumerate(train_loader):
        spectrograms, labels = spectrograms.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(spectrograms)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        if (batch_idx + 1) % print_freq == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}")

    epoch_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss}")

    # Update learning rate
    scheduler.step()
    print(f"Updated Learning Rate: {scheduler.get_last_lr()}")

    # Validation step
    model.eval()
    val_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for spectrograms, labels in val_loader:
            spectrograms, labels = spectrograms.to(device), labels.to(device)
            outputs = model(spectrograms)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            # Compute accuracy
            predicted = (torch.sigmoid(outputs) > 0.5).float()  # Convert logits to binary predictions

            # Store for metric computation
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    val_loss /= len(val_loader)

    # Convert lists to numpy arrays for metric calculations
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)

    # Compute metrics
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average="macro", zero_division=0)
    recall = recall_score(all_labels, all_preds, average="macro", zero_division=0)
    f1 = f1_score(all_labels, all_preds, average="macro", zero_division=0)

    # Print classification report
    class_names = train_dataset.label_map
    print(classification_report(all_labels, all_preds, target_names=class_names))

    print(f"\nValidation Loss: {val_loss:.4f}, Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}\n")

    torch.save(model.state_dict(), model_save_path)
    print(f"Model saved to {model_save_path}")
# Out:
# Epoch [1/5], Batch [10/4062], Loss: 0.3554
# Epoch [1/5], Batch [20/4062], Loss: 0.3425
# Epoch [1/5], Batch [30/4062], Loss: 0.3230
# Epoch [1/5], Batch [40/4062], Loss: 0.3011
# Epoch [1/5], Batch [50/4062], Loss: 0.2667
# Epoch [1/5], Batch [60/4062], Loss: 0.2126
# Epoch [1/5], Batch [70/4062], Loss: 0.2275
# Epoch [1/5], Batch [80/4062], Loss: 0.1884
# Epoch [1/5], Batch [90/4062], Loss: 0.1897
# Epoch [1/5], Batch [100/4062], Loss: 0.2082
# Epoch [1/5], Batch [110/4062], Loss: 0.1314
# Epoch [1/5], Batch [120/4062], Loss: 0.1471
# Epoch [1/5], Batch [130/4062], Loss: 0.1383
# Epoch [1/5], Batch [140/4062], Loss: 0.1162
# Epoch [1/5], Batch [150/4062], Loss: 0.1523
# Epoch [1/5], Batch [160/4062], Loss: 0.1378
# Epoch [1/5], Batch [170/4062], Loss: 0.1390
# Epoch [1/5], Batch [180/4062], Loss: 0.0909
# Epoch [1/5], Batch [190/4062], Loss: 0.1046
# Epoch [1/5], Batch [200/4062], Loss: 0.1133
# Epoch [1/5], Batch [210/4062], Loss: 0.0935
# Epoch [1/5], Batch [220/4062], Loss: 0.1059
# Epoch [1/5], Batch [230/4062], Loss: 0.0888
# Epoch [1/5], Batch [240/4062], Loss: 0.0732
# Epoch [1/5], Batch [250/4062], Loss: 0.0916
# Epoch [1/5], Batch [260/4062], Loss: 0.0836
# Epoch [1/5], Batch [270/4062], Loss: 0.0864
# Epoch [1/5], Batch [280/4062], Loss: 0.0742
# Epoch [1/5], Batch [290/4062], Loss: 0.0625
# Epoch [1/5], Batch [300/4062], Loss: 0.0711
# Epoch [1/5], Batch [310/4062], Loss: 0.1081
# Epoch [1/5], Batch [320/4062], Loss: 0.0696
# Epoch [1/5], Batch [330/4062], Loss: 0.0702
# Epoch [1/5], Batch [340/4062], Loss: 0.0560
# Epoch [1/5], Batch [350/4062], Loss: 0.0591
# Epoch [1/5], Batch [360/4062], Loss: 0.0848
# Epoch [1/5], Batch [370/4062], Loss: 0.0525
# Epoch [1/5], Batch [380/4062], Loss: 0.0436
# Epoch [1/5], Batch [390/4062], Loss: 0.0822
# Epoch [1/5], Batch [400/4062], Loss: 0.0932
# Epoch [1/5], Batch [410/4062], Loss: 0.0608
# Epoch [1/5], Batch [420/4062], Loss: 0.0704
# Epoch [1/5], Batch [430/4062], Loss: 0.0641
# Epoch [1/5], Batch [440/4062], Loss: 0.0675
# Epoch [1/5], Batch [450/4062], Loss: 0.0435
# Epoch [1/5], Batch [460/4062], Loss: 0.0358
# Epoch [1/5], Batch [470/4062], Loss: 0.0593
# Epoch [1/5], Batch [480/4062], Loss: 0.0467
# Epoch [1/5], Batch [490/4062], Loss: 0.0602
# Epoch [1/5], Batch [500/4062], Loss: 0.0465
# Epoch [1/5], Batch [510/4062], Loss: 0.0475
# Epoch [1/5], Batch [520/4062], Loss: 0.0627
# Epoch [1/5], Batch [530/4062], Loss: 0.0498
# Epoch [1/5], Batch [540/4062], Loss: 0.0427
# Epoch [1/5], Batch [550/4062], Loss: 0.0459
# Epoch [1/5], Batch [560/4062], Loss: 0.0574
# Epoch [1/5], Batch [570/4062], Loss: 0.0538
# Epoch [1/5], Batch [580/4062], Loss: 0.0704
# Epoch [1/5], Batch [590/4062], Loss: 0.0414
# Epoch [1/5], Batch [600/4062], Loss: 0.0491
# Epoch [1/5], Batch [610/4062], Loss: 0.0472
# Epoch [1/5], Batch [620/4062], Loss: 0.0617
# Epoch [1/5], Batch [630/4062], Loss: 0.0534
# Epoch [1/5], Batch [640/4062], Loss: 0.0579
# Epoch [1/5], Batch [650/4062], Loss: 0.0355
# Epoch [1/5], Batch [660/4062], Loss: 0.0306
# Epoch [1/5], Batch [670/4062], Loss: 0.0350
# Epoch [1/5], Batch [680/4062], Loss: 0.0407
# Epoch [1/5], Batch [690/4062], Loss: 0.0319
# Epoch [1/5], Batch [700/4062], Loss: 0.0355
# Epoch [1/5], Batch [710/4062], Loss: 0.0359
# Epoch [1/5], Batch [720/4062], Loss: 0.0390
# Epoch [1/5], Batch [730/4062], Loss: 0.0546
# Epoch [1/5], Batch [740/4062], Loss: 0.0454
# Epoch [1/5], Batch [750/4062], Loss: 0.0569
# Epoch [1/5], Batch [760/4062], Loss: 0.0345
# Epoch [1/5], Batch [770/4062], Loss: 0.0472
# Epoch [1/5], Batch [780/4062], Loss: 0.0393
# Epoch [1/5], Batch [790/4062], Loss: 0.0280
# Epoch [1/5], Batch [800/4062], Loss: 0.0623
# Epoch [1/5], Batch [810/4062], Loss: 0.0593
# Epoch [1/5], Batch [820/4062], Loss: 0.0404
# Epoch [1/5], Batch [830/4062], Loss: 0.0454
# Epoch [1/5], Batch [840/4062], Loss: 0.0355
# Epoch [1/5], Batch [850/4062], Loss: 0.0411
# Epoch [1/5], Batch [860/4062], Loss: 0.0250
# Epoch [1/5], Batch [870/4062], Loss: 0.0198
# Epoch [1/5], Batch [880/4062], Loss: 0.0328
# Epoch [1/5], Batch [890/4062], Loss: 0.0226
# Epoch [1/5], Batch [900/4062], Loss: 0.0343
# Epoch [1/5], Batch [910/4062], Loss: 0.0611
# Epoch [1/5], Batch [920/4062], Loss: 0.0475
# Epoch [1/5], Batch [930/4062], Loss: 0.0264
# Epoch [1/5], Batch [940/4062], Loss: 0.0129
# Epoch [1/5], Batch [950/4062], Loss: 0.0647
# Epoch [1/5], Batch [960/4062], Loss: 0.0267
# Epoch [1/5], Batch [970/4062], Loss: 0.0288
# Epoch [1/5], Batch [980/4062], Loss: 0.0169
# Epoch [1/5], Batch [990/4062], Loss: 0.0199
# Epoch [1/5], Batch [1000/4062], Loss: 0.0181
# Epoch [1/5], Batch [1010/4062], Loss: 0.0138
# Epoch [1/5], Batch [1020/4062], Loss: 0.0281
# Epoch [1/5], Batch [1030/4062], Loss: 0.0312
# Epoch [1/5], Batch [1040/4062], Loss: 0.0329
# Epoch [1/5], Batch [1050/4062], Loss: 0.0485
# Epoch [1/5], Batch [1060/4062], Loss: 0.0191
# Epoch [1/5], Batch [1070/4062], Loss: 0.0471
# Epoch [1/5], Batch [1080/4062], Loss: 0.0176
# Epoch [1/5], Batch [1090/4062], Loss: 0.0453
# Epoch [1/5], Batch [1100/4062], Loss: 0.0199
# Epoch [1/5], Batch [1110/4062], Loss: 0.0234
# Epoch [1/5], Batch [1120/4062], Loss: 0.0192
# Epoch [1/5], Batch [1130/4062], Loss: 0.0430
# Epoch [1/5], Batch [1140/4062], Loss: 0.0175
# Epoch [1/5], Batch [1150/4062], Loss: 0.0226
# Epoch [1/5], Batch [1160/4062], Loss: 0.0143
# Epoch [1/5], Batch [1170/4062], Loss: 0.0337
# Epoch [1/5], Batch [1180/4062], Loss: 0.0203
# Epoch [1/5], Batch [1190/4062], Loss: 0.0079
# Epoch [1/5], Batch [1200/4062], Loss: 0.0239
# Epoch [1/5], Batch [1210/4062], Loss: 0.0338
# Epoch [1/5], Batch [1220/4062], Loss: 0.0137
# Epoch [1/5], Batch [1230/4062], Loss: 0.0106
# Epoch [1/5], Batch [1240/4062], Loss: 0.0366
# Epoch [1/5], Batch [1250/4062], Loss: 0.0124
# Epoch [1/5], Batch [1260/4062], Loss: 0.0133
# Epoch [1/5], Batch [1270/4062], Loss: 0.0115
# Epoch [1/5], Batch [1280/4062], Loss: 0.0173
# Epoch [1/5], Batch [1290/4062], Loss: 0.0181
# Epoch [1/5], Batch [1300/4062], Loss: 0.0227
# Epoch [1/5], Batch [1310/4062], Loss: 0.0170
# Epoch [1/5], Batch [1320/4062], Loss: 0.0452
# Epoch [1/5], Batch [1330/4062], Loss: 0.0153
# Epoch [1/5], Batch [1340/4062], Loss: 0.0278
# Epoch [1/5], Batch [1350/4062], Loss: 0.0114
# Epoch [1/5], Batch [1360/4062], Loss: 0.0229
# Epoch [1/5], Batch [1370/4062], Loss: 0.0081
# Epoch [1/5], Batch [1380/4062], Loss: 0.0583
# Epoch [1/5], Batch [1390/4062], Loss: 0.0228
# Epoch [1/5], Batch [1400/4062], Loss: 0.0056
# Epoch [1/5], Batch [2920/4062], Loss: 0.0221
# Epoch [1/5], Batch [2930/4062], Loss: 0.0207
# Epoch [1/5], Batch [2940/4062], Loss: 0.0055
# Epoch [1/5], Batch [2950/4062], Loss: 0.0407
# Epoch [1/5], Batch [2960/4062], Loss: 0.0181
# Epoch [1/5], Batch [2970/4062], Loss: 0.0072
# Epoch [1/5], Batch [2980/4062], Loss: 0.0150
# Epoch [1/5], Batch [2990/4062], Loss: 0.0112
# Epoch [1/5], Batch [3000/4062], Loss: 0.0098
# Epoch [1/5], Batch [3010/4062], Loss: 0.0228
# Epoch [1/5], Batch [3020/4062], Loss: 0.0045
# Epoch [1/5], Batch [3030/4062], Loss: 0.0134
# Epoch [1/5], Batch [3040/4062], Loss: 0.0425
# Epoch [1/5], Batch [3050/4062], Loss: 0.0103
# Epoch [1/5], Batch [3060/4062], Loss: 0.0102
# Epoch [1/5], Batch [3070/4062], Loss: 0.0047
# Epoch [1/5], Batch [3080/4062], Loss: 0.0165
# Epoch [1/5], Batch [3090/4062], Loss: 0.0125
# Epoch [1/5], Batch [3100/4062], Loss: 0.0317
# Epoch [1/5], Batch [3110/4062], Loss: 0.0235
# Epoch [1/5], Batch [3120/4062], Loss: 0.0280
# Epoch [1/5], Batch [3130/4062], Loss: 0.0049
# Epoch [1/5], Batch [3140/4062], Loss: 0.0275
# Epoch [1/5], Batch [3150/4062], Loss: 0.0150
# Epoch [1/5], Batch [3160/4062], Loss: 0.0157
# Epoch [1/5], Batch [3170/4062], Loss: 0.0057
# Epoch [1/5], Batch [3180/4062], Loss: 0.0317
# Epoch [1/5], Batch [3190/4062], Loss: 0.0211
# Epoch [1/5], Batch [3200/4062], Loss: 0.0020
# Epoch [1/5], Batch [3210/4062], Loss: 0.0328
# Epoch [1/5], Batch [3220/4062], Loss: 0.0133
# Epoch [1/5], Batch [3230/4062], Loss: 0.0078
# Epoch [1/5], Batch [3240/4062], Loss: 0.0095
# Epoch [1/5], Batch [3250/4062], Loss: 0.0136
# Epoch [1/5], Batch [3260/4062], Loss: 0.0166
# Epoch [1/5], Batch [3270/4062], Loss: 0.0147
# Epoch [1/5], Batch [3280/4062], Loss: 0.0227
# Epoch [1/5], Batch [3290/4062], Loss: 0.0051
# Epoch [1/5], Batch [3300/4062], Loss: 0.0265
# Epoch [1/5], Batch [3310/4062], Loss: 0.0038
# Epoch [1/5], Batch [3320/4062], Loss: 0.0056
# Epoch [1/5], Batch [3330/4062], Loss: 0.0047
# Epoch [1/5], Batch [3340/4062], Loss: 0.0414
# Epoch [1/5], Batch [3350/4062], Loss: 0.0047
# Epoch [1/5], Batch [3360/4062], Loss: 0.0062
# Epoch [1/5], Batch [3370/4062], Loss: 0.0022
# Epoch [1/5], Batch [3380/4062], Loss: 0.0065
# Epoch [1/5], Batch [3390/4062], Loss: 0.0395
# Epoch [1/5], Batch [3400/4062], Loss: 0.0041
# Epoch [1/5], Batch [3410/4062], Loss: 0.0140
# Epoch [1/5], Batch [3420/4062], Loss: 0.0104
# Epoch [1/5], Batch [3930/4062], Loss: 0.0220
# Epoch [1/5], Batch [3940/4062], Loss: 0.0239
# Epoch [1/5], Batch [3950/4062], Loss: 0.0107
# Epoch [1/5], Batch [3960/4062], Loss: 0.0072
# Epoch [1/5], Batch [3970/4062], Loss: 0.0134
# Epoch [1/5], Batch [3980/4062], Loss: 0.0054
# Epoch [1/5], Batch [3990/4062], Loss: 0.0232
# Epoch [1/5], Batch [4000/4062], Loss: 0.0081
# Epoch [1/5], Batch [4010/4062], Loss: 0.0148
# Epoch [1/5], Batch [4020/4062], Loss: 0.0517
# Epoch [1/5], Batch [4030/4062], Loss: 0.0188
# Epoch [1/5], Batch [4040/4062], Loss: 0.0227
# Epoch [1/5], Batch [4050/4062], Loss: 0.0227
# Epoch [1/5], Batch [4060/4062], Loss: 0.0056
# Epoch 1/5, Loss: 0.034413404904194395
# Updated Learning Rate: [0.000199]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#    overdrive       1.00      0.95      0.97      3012
#   distortion       0.97      1.00      0.98      4518
#         fuzz       0.99      1.00      1.00      5271
#      tremolo       1.00      1.00      1.00      3765
#       phaser       0.98      1.00      0.99      4518
#      flanger       0.98      0.98      0.98      3012
#       chorus       0.99      1.00      1.00      5271
#        delay       0.98      0.97      0.98      6777
#  hall_reverb       0.90      0.96      0.93      4518
# plate_reverb       0.96      0.98      0.97      3012
#      octaver       0.97      1.00      0.98      2259
#  auto_filter       1.00      0.99      1.00      3765
#
#    micro avg       0.98      0.98      0.98     49698
#    macro avg       0.98      0.98      0.98     49698
# weighted avg       0.98      0.98      0.98     49698
#  samples avg       0.95      0.96      0.95     49698
#
#
# Validation Loss: 0.0151, Accuracy: 0.9445, Precision: 0.9781, Recall: 0.9845, F1-score: 0.9811
#
# Model saved to /content/drive/MyDrive/W210/Models/last_model.mod
# Epoch [2/5], Batch [10/4062], Loss: 0.0072
# Epoch [2/5], Batch [20/4062], Loss: 0.0045
# Epoch [2/5], Batch [30/4062], Loss: 0.0100
# Epoch [2/5], Batch [40/4062], Loss: 0.0044
# Epoch [2/5], Batch [50/4062], Loss: 0.0111
# Epoch [2/5], Batch [60/4062], Loss: 0.0087
# Epoch [2/5], Batch [70/4062], Loss: 0.0244
# Epoch [2/5], Batch [80/4062], Loss: 0.0261
# Epoch [2/5], Batch [90/4062], Loss: 0.0054
# Epoch [2/5], Batch [100/4062], Loss: 0.0006
# Epoch [2/5], Batch [110/4062], Loss: 0.0057
# Epoch [2/5], Batch [120/4062], Loss: 0.0059
# Epoch [2/5], Batch [130/4062], Loss: 0.0147
# Epoch [2/5], Batch [140/4062], Loss: 0.0185
# Epoch [2/5], Batch [150/4062], Loss: 0.0046
# Epoch [2/5], Batch [160/4062], Loss: 0.0144
# Epoch [2/5], Batch [170/4062], Loss: 0.0055
# Epoch [2/5], Batch [180/4062], Loss: 0.0078
# Epoch [2/5], Batch [190/4062], Loss: 0.0016
# Epoch [2/5], Batch [200/4062], Loss: 0.0072
# Epoch [2/5], Batch [210/4062], Loss: 0.0111
# Epoch [2/5], Batch [3770/4062], Loss: 0.0003
# Epoch [2/5], Batch [3780/4062], Loss: 0.0039
# Epoch [2/5], Batch [3790/4062], Loss: 0.0095
# Epoch [2/5], Batch [3800/4062], Loss: 0.0026
# Epoch [2/5], Batch [3810/4062], Loss: 0.0003
# Epoch [2/5], Batch [3820/4062], Loss: 0.0054
# Epoch [2/5], Batch [3830/4062], Loss: 0.0039
# Epoch [2/5], Batch [3840/4062], Loss: 0.0031
# Epoch [2/5], Batch [3850/4062], Loss: 0.0010
# Epoch [2/5], Batch [3860/4062], Loss: 0.0012
# Epoch [2/5], Batch [3870/4062], Loss: 0.0004
# Epoch [2/5], Batch [3880/4062], Loss: 0.0026
# Epoch [2/5], Batch [3890/4062], Loss: 0.0071
# Epoch [2/5], Batch [3900/4062], Loss: 0.0040
# Epoch [2/5], Batch [3910/4062], Loss: 0.0102
# Epoch [2/5], Batch [3920/4062], Loss: 0.0014
# Epoch [2/5], Batch [3930/4062], Loss: 0.0023
# Epoch [2/5], Batch [3940/4062], Loss: 0.0009
# Epoch [2/5], Batch [3950/4062], Loss: 0.0017
# Epoch [2/5], Batch [3960/4062], Loss: 0.0187
# Epoch [2/5], Batch [3970/4062], Loss: 0.0222
# Epoch [2/5], Batch [3980/4062], Loss: 0.0053
# Epoch [2/5], Batch [3990/4062], Loss: 0.0369
# Epoch [2/5], Batch [4000/4062], Loss: 0.0006
# Epoch [2/5], Batch [4010/4062], Loss: 0.0028
# Epoch [2/5], Batch [4020/4062], Loss: 0.0015
# Epoch [2/5], Batch [4030/4062], Loss: 0.0484
# Epoch [2/5], Batch [4040/4062], Loss: 0.0032
# Epoch [2/5], Batch [4050/4062], Loss: 0.0093
# Epoch [2/5], Batch [4060/4062], Loss: 0.0034
# Epoch 2/5, Loss: 0.0065455262175279924
# Updated Learning Rate: [7.9202e-05]
#               precision    recall  f1-score   support
#
#    overdrive       0.91      1.00      0.95      3012
#   distortion       0.99      1.00      1.00      4518
#         fuzz       1.00      1.00      1.00      5271
#      tremolo       1.00      1.00      1.00      3765
#       phaser       1.00      0.98      0.99      4518
#      flanger       1.00      0.97      0.98      3012
#       chorus       0.98      1.00      0.99      5271
#        delay       0.99      0.98      0.98      6777
#  hall_reverb       0.91      0.97      0.94      4518
# plate_reverb       0.98      0.98      0.98      3012
#      octaver       0.99      0.99      0.99      2259
#  auto_filter       1.00      0.99      1.00      3765
#
#    micro avg       0.98      0.99      0.98     49698
#    macro avg       0.98      0.99      0.98     49698
# weighted avg       0.98      0.99      0.98     49698
#  samples avg       0.95      0.96      0.95     49698
#
#
# Validation Loss: 0.0137, Accuracy: 0.9503, Precision: 0.9784, Recall: 0.9878, F1-score: 0.9828
#
# Model saved to /content/drive/MyDrive/W210/Models/last_model.mod
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch [3/5], Batch [10/4062], Loss: 0.0129
# Epoch [3/5], Batch [20/4062], Loss: 0.0062
# Epoch [3/5], Batch [30/4062], Loss: 0.0057
# Epoch [3/5], Batch [40/4062], Loss: 0.0024
# Epoch [3/5], Batch [50/4062], Loss: 0.0016
# Epoch [3/5], Batch [60/4062], Loss: 0.0051
# Epoch [3/5], Batch [70/4062], Loss: 0.0006
# Epoch [3/5], Batch [80/4062], Loss: 0.0026
# Epoch [3/5], Batch [90/4062], Loss: 0.0116
# Epoch [3/5], Batch [100/4062], Loss: 0.0010
# Epoch [3/5], Batch [110/4062], Loss: 0.0125
# Epoch [3/5], Batch [120/4062], Loss: 0.0036
# Epoch [3/5], Batch [130/4062], Loss: 0.0010
# Epoch [3/5], Batch [140/4062], Loss: 0.0011
# Epoch [3/5], Batch [150/4062], Loss: 0.0068
# Epoch [3/5], Batch [160/4062], Loss: 0.0031
# Epoch [3/5], Batch [170/4062], Loss: 0.0003
# Epoch [3/5], Batch [180/4062], Loss: 0.0015
# Epoch [3/5], Batch [190/4062], Loss: 0.0004
# Epoch [3/5], Batch [200/4062], Loss: 0.0014
# Epoch [3/5], Batch [210/4062], Loss: 0.0038
# Epoch [3/5], Batch [220/4062], Loss: 0.0012
# Epoch [3/5], Batch [230/4062], Loss: 0.0182
# Epoch [3/5], Batch [240/4062], Loss: 0.0018
# Epoch [3/5], Batch [250/4062], Loss: 0.0018
# Epoch [3/5], Batch [260/4062], Loss: 0.0006
# Epoch [3/5], Batch [270/4062], Loss: 0.0014
# Epoch [3/5], Batch [280/4062], Loss: 0.0016
# Epoch [3/5], Batch [290/4062], Loss: 0.0005
# Epoch [3/5], Batch [300/4062], Loss: 0.0122
# Epoch [3/5], Batch [310/4062], Loss: 0.0023
# Epoch [3/5], Batch [320/4062], Loss: 0.0021
# Epoch [3/5], Batch [330/4062], Loss: 0.0013
# Epoch [3/5], Batch [340/4062], Loss: 0.0007
# Epoch [3/5], Batch [350/4062], Loss: 0.0026
# Epoch [3/5], Batch [360/4062], Loss: 0.0006
# Epoch [3/5], Batch [370/4062], Loss: 0.0074
# Epoch [3/5], Batch [380/4062], Loss: 0.0035
# Epoch [3/5], Batch [390/4062], Loss: 0.0086
# Epoch [3/5], Batch [400/4062], Loss: 0.0006
# Epoch [3/5], Batch [410/4062], Loss: 0.0013
# Epoch [3/5], Batch [420/4062], Loss: 0.0007
# Epoch [3/5], Batch [430/4062], Loss: 0.0052
# Epoch [3/5], Batch [440/4062], Loss: 0.0018
# Epoch [3/5], Batch [450/4062], Loss: 0.0017
# Epoch [3/5], Batch [460/4062], Loss: 0.0006
# Epoch [3/5], Batch [470/4062], Loss: 0.0063
# Epoch [3/5], Batch [480/4062], Loss: 0.0005
# Epoch [3/5], Batch [490/4062], Loss: 0.0027
# Epoch [3/5], Batch [500/4062], Loss: 0.0034
# Epoch [3/5], Batch [510/4062], Loss: 0.0067
# Epoch [3/5], Batch [520/4062], Loss: 0.0044
# Epoch [3/5], Batch [530/4062], Loss: 0.0001
# Epoch [3/5], Batch [540/4062], Loss: 0.0003
# Epoch [3/5], Batch [550/4062], Loss: 0.0041
# Epoch [3/5], Batch [560/4062], Loss: 0.0005
# Epoch [3/5], Batch [570/4062], Loss: 0.0040
# Epoch [3/5], Batch [580/4062], Loss: 0.0042
# Epoch [3/5], Batch [590/4062], Loss: 0.0002
# Epoch [3/5], Batch [600/4062], Loss: 0.0099
# Epoch [3/5], Batch [610/4062], Loss: 0.0014
# Epoch [3/5], Batch [620/4062], Loss: 0.0013
# Epoch [3/5], Batch [630/4062], Loss: 0.0014
# Epoch [3/5], Batch [640/4062], Loss: 0.0341
# Epoch [3/5], Batch [650/4062], Loss: 0.0068
# Epoch [3/5], Batch [660/4062], Loss: 0.0005
# Epoch [3/5], Batch [670/4062], Loss: 0.0015
# Epoch [3/5], Batch [680/4062], Loss: 0.0095
# Epoch [3/5], Batch [690/4062], Loss: 0.0046
# Epoch [3/5], Batch [700/4062], Loss: 0.0011
# Epoch [3/5], Batch [710/4062], Loss: 0.0082
# Epoch [3/5], Batch [720/4062], Loss: 0.0120
# Epoch [3/5], Batch [730/4062], Loss: 0.0003
# Epoch [3/5], Batch [740/4062], Loss: 0.0048
# Epoch [3/5], Batch [750/4062], Loss: 0.0059
# Epoch [3/5], Batch [760/4062], Loss: 0.0079
# Epoch [3/5], Batch [770/4062], Loss: 0.0007
# Epoch [3/5], Batch [780/4062], Loss: 0.0070
# Epoch [3/5], Batch [790/4062], Loss: 0.0005
# Epoch [3/5], Batch [800/4062], Loss: 0.0043
# Epoch [3/5], Batch [810/4062], Loss: 0.0064
# Epoch [3/5], Batch [820/4062], Loss: 0.0011
# Epoch [3/5], Batch [830/4062], Loss: 0.0002
# Epoch [3/5], Batch [840/4062], Loss: 0.0008
# Epoch [3/5], Batch [850/4062], Loss: 0.0004
# Epoch [3/5], Batch [860/4062], Loss: 0.0010
# Epoch [3/5], Batch [870/4062], Loss: 0.0002
# Epoch [3/5], Batch [880/4062], Loss: 0.0079
# Epoch [3/5], Batch [890/4062], Loss: 0.0041
# Epoch [3/5], Batch [900/4062], Loss: 0.0129
# Epoch [3/5], Batch [910/4062], Loss: 0.0018
# Epoch [3/5], Batch [920/4062], Loss: 0.0026
# Epoch [3/5], Batch [930/4062], Loss: 0.0003
# Epoch [3/5], Batch [940/4062], Loss: 0.0008
# Epoch [3/5], Batch [950/4062], Loss: 0.0099
# Epoch [3/5], Batch [960/4062], Loss: 0.0017
# Epoch [3/5], Batch [970/4062], Loss: 0.0010
# Epoch [3/5], Batch [980/4062], Loss: 0.0004
# Epoch [3/5], Batch [990/4062], Loss: 0.0005
# Epoch [3/5], Batch [1000/4062], Loss: 0.0076
# Epoch [3/5], Batch [1010/4062], Loss: 0.0014
# Epoch [3/5], Batch [1020/4062], Loss: 0.0008
# Epoch [3/5], Batch [1030/4062], Loss: 0.0002
# Epoch [3/5], Batch [1040/4062], Loss: 0.0087
# Epoch [3/5], Batch [1050/4062], Loss: 0.0006
# Epoch [3/5], Batch [1060/4062], Loss: 0.0008
# Epoch [3/5], Batch [1070/4062], Loss: 0.0023
# Epoch [3/5], Batch [1080/4062], Loss: 0.0015
# Epoch [3/5], Batch [1090/4062], Loss: 0.0013
# Epoch [3/5], Batch [1100/4062], Loss: 0.0035
# Epoch [3/5], Batch [1110/4062], Loss: 0.0025
# Epoch [3/5], Batch [1120/4062], Loss: 0.0043
# Epoch [3/5], Batch [1130/4062], Loss: 0.0002
# Epoch [3/5], Batch [1140/4062], Loss: 0.0038
# Epoch [3/5], Batch [1150/4062], Loss: 0.0005
# Epoch [3/5], Batch [1160/4062], Loss: 0.0070
# Epoch [3/5], Batch [1170/4062], Loss: 0.0019
# Epoch [3/5], Batch [1180/4062], Loss: 0.0159
# Epoch [3/5], Batch [1190/4062], Loss: 0.0049
# Epoch [3/5], Batch [1200/4062], Loss: 0.0009
# Epoch [3/5], Batch [1210/4062], Loss: 0.0011
# Epoch [3/5], Batch [1220/4062], Loss: 0.0139
# Epoch [3/5], Batch [1230/4062], Loss: 0.0014
# Epoch [3/5], Batch [1240/4062], Loss: 0.0164
# Epoch [3/5], Batch [1250/4062], Loss: 0.0163
# Epoch [3/5], Batch [1260/4062], Loss: 0.0164
# Epoch [3/5], Batch [1270/4062], Loss: 0.0003
# Epoch [3/5], Batch [1280/4062], Loss: 0.0008
# Epoch [3/5], Batch [1290/4062], Loss: 0.0103
# Epoch [3/5], Batch [1300/4062], Loss: 0.0001
# Epoch [3/5], Batch [1310/4062], Loss: 0.0026
# Epoch [3/5], Batch [1320/4062], Loss: 0.0008
# Epoch [3/5], Batch [1330/4062], Loss: 0.0013
# Epoch [3/5], Batch [1340/4062], Loss: 0.0001
# Epoch [3/5], Batch [1350/4062], Loss: 0.0686
# Epoch [3/5], Batch [1360/4062], Loss: 0.0002
# Epoch [3/5], Batch [1370/4062], Loss: 0.0019
# Epoch [3/5], Batch [1380/4062], Loss: 0.0001
# Epoch [3/5], Batch [1390/4062], Loss: 0.0008
# Epoch [3/5], Batch [1400/4062], Loss: 0.0008
# Epoch [3/5], Batch [1410/4062], Loss: 0.0000
# Epoch [3/5], Batch [1420/4062], Loss: 0.0002
# Epoch [3/5], Batch [1430/4062], Loss: 0.0045
# Epoch [3/5], Batch [1440/4062], Loss: 0.0042
# Epoch [3/5], Batch [1450/4062], Loss: 0.0032
# Epoch [3/5], Batch [1460/4062], Loss: 0.0001
# Epoch [3/5], Batch [1470/4062], Loss: 0.0025
# Epoch [3/5], Batch [1480/4062], Loss: 0.0005
# Epoch [3/5], Batch [1490/4062], Loss: 0.0087
# Epoch [3/5], Batch [1500/4062], Loss: 0.0001
# Epoch [3/5], Batch [1510/4062], Loss: 0.0009
# Epoch [3/5], Batch [1520/4062], Loss: 0.0006
# Epoch [3/5], Batch [1530/4062], Loss: 0.0001
# Epoch [3/5], Batch [1540/4062], Loss: 0.0079
# Epoch [3/5], Batch [1550/4062], Loss: 0.0035
# Epoch [3/5], Batch [1560/4062], Loss: 0.0028
# Epoch [3/5], Batch [1570/4062], Loss: 0.0008
# Epoch [3/5], Batch [1580/4062], Loss: 0.0056
# Epoch [3/5], Batch [1590/4062], Loss: 0.0003
# Epoch [3/5], Batch [1600/4062], Loss: 0.0012
# Epoch [3/5], Batch [1610/4062], Loss: 0.0033
# Epoch [3/5], Batch [1620/4062], Loss: 0.0031
# Epoch [3/5], Batch [1630/4062], Loss: 0.0000
# Epoch [3/5], Batch [1640/4062], Loss: 0.0001
# Epoch [3/5], Batch [1650/4062], Loss: 0.0002
# Epoch [3/5], Batch [1660/4062], Loss: 0.0033
# Epoch [3/5], Batch [1670/4062], Loss: 0.0017
# Epoch [3/5], Batch [1680/4062], Loss: 0.0024
# ...
# Epoch [5/5], Batch [990/4062], Loss: 0.0018
# Epoch [5/5], Batch [1000/4062], Loss: 0.0004
# Epoch [5/5], Batch [1010/4062], Loss: 0.0006
# Epoch [5/5], Batch [1020/4062], Loss: 0.0007
# Epoch [5/5], Batch [1030/4062], Loss: 0.0026
# Epoch [5/5], Batch [1040/4062], Loss: 0.0000
# Epoch [5/5], Batch [1050/4062], Loss: 0.0002
# Epoch [5/5], Batch [1060/4062], Loss: 0.0064
# Epoch [5/5], Batch [1070/4062], Loss: 0.0112
# Epoch [5/5], Batch [1080/4062], Loss: 0.0030
# Epoch [5/5], Batch [1090/4062], Loss: 0.0017
# Epoch [5/5], Batch [1100/4062], Loss: 0.0136
# Epoch [5/5], Batch [1110/4062], Loss: 0.0013
# Epoch [5/5], Batch [1120/4062], Loss: 0.0001
# Epoch [5/5], Batch [1130/4062], Loss: 0.0001
# Epoch [5/5], Batch [1140/4062], Loss: 0.0001
# Epoch [5/5], Batch [1150/4062], Loss: 0.0017
# Epoch [5/5], Batch [1160/4062], Loss: 0.0116
# Epoch [5/5], Batch [1170/4062], Loss: 0.0017
# Epoch [5/5], Batch [1180/4062], Loss: 0.0012
# Epoch [5/5], Batch [1190/4062], Loss: 0.0000
# Epoch [5/5], Batch [1200/4062], Loss: 0.0049
# Epoch [5/5], Batch [1210/4062], Loss: 0.0006
# Epoch [5/5], Batch [1220/4062], Loss: 0.0002
# Epoch [5/5], Batch [1230/4062], Loss: 0.0068
# Epoch [5/5], Batch [1240/4062], Loss: 0.0001
# Epoch [5/5], Batch [1250/4062], Loss: 0.0009
# Epoch [5/5], Batch [1260/4062], Loss: 0.0006
# Epoch [5/5], Batch [1270/4062], Loss: 0.0001
# Epoch [5/5], Batch [1280/4062], Loss: 0.0023
# Epoch [5/5], Batch [1290/4062], Loss: 0.0002
# Epoch [5/5], Batch [1300/4062], Loss: 0.0216
# Epoch [5/5], Batch [1310/4062], Loss: 0.0012
# Epoch [5/5], Batch [1320/4062], Loss: 0.0001
# Epoch [5/5], Batch [1330/4062], Loss: 0.0009
# Epoch [5/5], Batch [1340/4062], Loss: 0.0001
# Epoch [5/5], Batch [1350/4062], Loss: 0.0083
# Epoch [5/5], Batch [1360/4062], Loss: 0.0040
# Epoch [5/5], Batch [1370/4062], Loss: 0.0012
# Epoch [5/5], Batch [1380/4062], Loss: 0.0007
# Epoch [5/5], Batch [1390/4062], Loss: 0.0001
# Epoch [5/5], Batch [1400/4062], Loss: 0.0024
# Epoch [5/5], Batch [1410/4062], Loss: 0.0002
# Epoch [5/5], Batch [1420/4062], Loss: 0.0001
# Epoch [5/5], Batch [1430/4062], Loss: 0.0005
# Epoch [5/5], Batch [1440/4062], Loss: 0.0001
# Epoch [5/5], Batch [1450/4062], Loss: 0.0001
# Epoch [5/5], Batch [1460/4062], Loss: 0.0002
# Epoch [5/5], Batch [1470/4062], Loss: 0.0111
# Epoch [5/5], Batch [1480/4062], Loss: 0.0099
# Epoch [5/5], Batch [1490/4062], Loss: 0.0004
# Epoch [5/5], Batch [1500/4062], Loss: 0.0011
# Epoch [5/5], Batch [1510/4062], Loss: 0.0112
# Epoch [5/5], Batch [1520/4062], Loss: 0.0001
# Epoch [5/5], Batch [1530/4062], Loss: 0.0002
# Epoch [5/5], Batch [1540/4062], Loss: 0.0207
# Epoch [5/5], Batch [1550/4062], Loss: 0.0001
# Epoch [5/5], Batch [1560/4062], Loss: 0.0001
# Epoch [5/5], Batch [1570/4062], Loss: 0.0002
# Epoch [5/5], Batch [1580/4062], Loss: 0.0001
# Epoch [5/5], Batch [1590/4062], Loss: 0.0002
# Epoch [5/5], Batch [1600/4062], Loss: 0.0014
# Epoch [5/5], Batch [1610/4062], Loss: 0.0010
# Epoch [5/5], Batch [1620/4062], Loss: 0.0009
# Epoch [5/5], Batch [1630/4062], Loss: 0.0030
# Epoch [5/5], Batch [1640/4062], Loss: 0.0108
# Epoch [5/5], Batch [1650/4062], Loss: 0.0015
# Epoch [5/5], Batch [1660/4062], Loss: 0.0002
# Epoch [5/5], Batch [1670/4062], Loss: 0.0007
# Epoch [5/5], Batch [1680/4062], Loss: 0.0032
# Epoch [5/5], Batch [1690/4062], Loss: 0.0008
# Epoch [5/5], Batch [1700/4062], Loss: 0.0007
# Epoch [5/5], Batch [1710/4062], Loss: 0.0000
# Epoch [5/5], Batch [1720/4062], Loss: 0.0005
# Epoch [5/5], Batch [1730/4062], Loss: 0.0018
# Epoch [5/5], Batch [1740/4062], Loss: 0.0001
# Epoch [5/5], Batch [1750/4062], Loss: 0.0005
# Epoch [5/5], Batch [1760/4062], Loss: 0.0006
# Epoch [5/5], Batch [1770/4062], Loss: 0.0006
# Epoch [5/5], Batch [1780/4062], Loss: 0.0067
# Epoch [5/5], Batch [1790/4062], Loss: 0.0001
# Epoch [5/5], Batch [1800/4062], Loss: 0.0006
# Epoch [5/5], Batch [1810/4062], Loss: 0.0007
# Epoch [5/5], Batch [1820/4062], Loss: 0.0004
# Epoch [5/5], Batch [1830/4062], Loss: 0.0002
# Epoch [5/5], Batch [1840/4062], Loss: 0.0000
# Epoch [5/5], Batch [1850/4062], Loss: 0.0097
# Epoch [5/5], Batch [1860/4062], Loss: 0.0226
# Epoch [5/5], Batch [1870/4062], Loss: 0.0001
# Epoch [5/5], Batch [1880/4062], Loss: 0.0001
# Epoch [5/5], Batch [1890/4062], Loss: 0.0001
# Epoch [5/5], Batch [1900/4062], Loss: 0.0001
# Epoch [5/5], Batch [1910/4062], Loss: 0.0001
# Epoch [5/5], Batch [1920/4062], Loss: 0.0000
# Epoch [5/5], Batch [1930/4062], Loss: 0.0002
# Epoch [5/5], Batch [1940/4062], Loss: 0.0128
# Epoch [5/5], Batch [1950/4062], Loss: 0.0020
# Epoch [5/5], Batch [1960/4062], Loss: 0.0000
# Epoch [5/5], Batch [1970/4062], Loss: 0.0013
# Epoch [5/5], Batch [1980/4062], Loss: 0.0056
# Epoch [5/5], Batch [1990/4062], Loss: 0.0047
# Epoch [5/5], Batch [2000/4062], Loss: 0.0000
# Epoch [5/5], Batch [2010/4062], Loss: 0.0013
# Epoch [5/5], Batch [2020/4062], Loss: 0.0152
# Epoch [5/5], Batch [2030/4062], Loss: 0.0001
# Epoch [5/5], Batch [2040/4062], Loss: 0.0009
# Epoch [5/5], Batch [2050/4062], Loss: 0.0048
# Epoch [5/5], Batch [2060/4062], Loss: 0.0149
# Epoch [5/5], Batch [2070/4062], Loss: 0.0002
# Epoch [5/5], Batch [2080/4062], Loss: 0.0001
# Epoch [5/5], Batch [2090/4062], Loss: 0.0004
# Epoch [5/5], Batch [2100/4062], Loss: 0.0003
# Epoch [5/5], Batch [2110/4062], Loss: 0.0001
# Epoch [5/5], Batch [2120/4062], Loss: 0.0000
# Epoch [5/5], Batch [2130/4062], Loss: 0.0000
# Epoch [5/5], Batch [2140/4062], Loss: 0.0001
# Epoch [5/5], Batch [2150/4062], Loss: 0.0005
# Epoch [5/5], Batch [2160/4062], Loss: 0.0197
# Epoch [5/5], Batch [2170/4062], Loss: 0.0010
# Epoch [5/5], Batch [2180/4062], Loss: 0.0000
# Epoch [5/5], Batch [2190/4062], Loss: 0.0004
# Epoch [5/5], Batch [2200/4062], Loss: 0.0009
# Epoch [5/5], Batch [2210/4062], Loss: 0.0003
# Epoch [5/5], Batch [2220/4062], Loss: 0.0000
# Epoch [5/5], Batch [2230/4062], Loss: 0.0013
# Epoch [5/5], Batch [2240/4062], Loss: 0.0000
# Epoch [5/5], Batch [2250/4062], Loss: 0.0002
# Epoch [5/5], Batch [2260/4062], Loss: 0.0015
# Epoch [5/5], Batch [2270/4062], Loss: 0.0003
# Epoch [5/5], Batch [2280/4062], Loss: 0.0001
# Epoch [5/5], Batch [2290/4062], Loss: 0.0084
# Epoch [5/5], Batch [2300/4062], Loss: 0.0005
# Epoch [5/5], Batch [2310/4062], Loss: 0.0013
# Epoch [5/5], Batch [2320/4062], Loss: 0.0075
# Epoch [5/5], Batch [2330/4062], Loss: 0.0011
# Epoch [5/5], Batch [2340/4062], Loss: 0.0002
# Epoch [5/5], Batch [2350/4062], Loss: 0.0003
# Epoch [5/5], Batch [2360/4062], Loss: 0.0027
# Epoch [5/5], Batch [2370/4062], Loss: 0.0005
# Epoch [5/5], Batch [2380/4062], Loss: 0.0028
# Epoch [5/5], Batch [2390/4062], Loss: 0.0003
# Epoch [5/5], Batch [2400/4062], Loss: 0.0130
# Epoch [5/5], Batch [2410/4062], Loss: 0.0003
# Epoch [5/5], Batch [2420/4062], Loss: 0.0005
# Epoch [5/5], Batch [2430/4062], Loss: 0.0008
# Epoch [5/5], Batch [2440/4062], Loss: 0.0002
# Epoch [5/5], Batch [2450/4062], Loss: 0.0107
# Epoch [5/5], Batch [2460/4062], Loss: 0.0013
# Epoch [5/5], Batch [2470/4062], Loss: 0.0119
# Epoch [5/5], Batch [2480/4062], Loss: 0.0014
# Epoch [5/5], Batch [2490/4062], Loss: 0.0000
# Epoch [5/5], Batch [2500/4062], Loss: 0.0012
# Epoch [5/5], Batch [2510/4062], Loss: 0.0127
# Epoch [5/5], Batch [2520/4062], Loss: 0.0088
# Epoch [5/5], Batch [2530/4062], Loss: 0.0001
# Epoch [5/5], Batch [2540/4062], Loss: 0.0006
# Epoch [5/5], Batch [2550/4062], Loss: 0.0019
# Epoch [5/5], Batch [2560/4062], Loss: 0.0018
# Epoch [5/5], Batch [2570/4062], Loss: 0.0065
# Epoch [5/5], Batch [2580/4062], Loss: 0.0002
# Epoch [5/5], Batch [2590/4062], Loss: 0.0000
# Epoch [5/5], Batch [2600/4062], Loss: 0.0005
# Epoch [5/5], Batch [2610/4062], Loss: 0.0158
# Epoch [5/5], Batch [2620/4062], Loss: 0.0002
# Epoch [5/5], Batch [2630/4062], Loss: 0.0001
# Epoch [5/5], Batch [2640/4062], Loss: 0.0016
# Epoch [5/5], Batch [2650/4062], Loss: 0.0000
# Epoch [5/5], Batch [2660/4062], Loss: 0.0000
# Epoch [5/5], Batch [2670/4062], Loss: 0.0008
# Epoch [5/5], Batch [2680/4062], Loss: 0.0001
# Epoch [5/5], Batch [2690/4062], Loss: 0.0001
# Epoch [5/5], Batch [2700/4062], Loss: 0.0001
# Epoch [5/5], Batch [2710/4062], Loss: 0.0008
# Epoch [5/5], Batch [2720/4062], Loss: 0.0020
# Epoch [5/5], Batch [2730/4062], Loss: 0.0005
# Epoch [5/5], Batch [2740/4062], Loss: 0.0000
# Epoch [5/5], Batch [2750/4062], Loss: 0.0001
# Epoch [5/5], Batch [2760/4062], Loss: 0.0030
# Epoch [5/5], Batch [2770/4062], Loss: 0.0011
# Epoch [5/5], Batch [2780/4062], Loss: 0.0049
# Epoch [5/5], Batch [2790/4062], Loss: 0.0035
# Epoch [5/5], Batch [2800/4062], Loss: 0.0006
# Epoch [5/5], Batch [2810/4062], Loss: 0.0001
# Epoch [5/5], Batch [2820/4062], Loss: 0.0001
# Epoch [5/5], Batch [2830/4062], Loss: 0.0153
# Epoch [5/5], Batch [2840/4062], Loss: 0.0006
# Epoch [5/5], Batch [2850/4062], Loss: 0.0005
# Epoch [5/5], Batch [2860/4062], Loss: 0.0004
# Epoch [5/5], Batch [2870/4062], Loss: 0.0013
# Epoch [5/5], Batch [2880/4062], Loss: 0.0002
# Epoch [5/5], Batch [2890/4062], Loss: 0.0105
# Epoch [5/5], Batch [2900/4062], Loss: 0.0002
# Epoch [5/5], Batch [2910/4062], Loss: 0.0030
# Epoch [5/5], Batch [2920/4062], Loss: 0.0002
# Epoch [5/5], Batch [2930/4062], Loss: 0.0084
# Epoch [5/5], Batch [2940/4062], Loss: 0.0009
# Epoch [5/5], Batch [2950/4062], Loss: 0.0008
# Epoch [5/5], Batch [2960/4062], Loss: 0.0020
# Epoch [5/5], Batch [2970/4062], Loss: 0.0000
# Epoch [5/5], Batch [2980/4062], Loss: 0.0000
# Epoch [5/5], Batch [2990/4062], Loss: 0.0006
# Epoch [5/5], Batch [3000/4062], Loss: 0.0006
# Epoch [5/5], Batch [3010/4062], Loss: 0.0015
# Epoch [5/5], Batch [3020/4062], Loss: 0.0001
# Epoch [5/5], Batch [3030/4062], Loss: 0.0004
# Epoch [5/5], Batch [3040/4062], Loss: 0.0004
# Epoch [5/5], Batch [3050/4062], Loss: 0.0012
# Epoch [5/5], Batch [3060/4062], Loss: 0.0001
# Epoch [5/5], Batch [3070/4062], Loss: 0.0005
# Epoch [5/5], Batch [3080/4062], Loss: 0.0134
# Epoch [5/5], Batch [3090/4062], Loss: 0.0002
# Epoch [5/5], Batch [3100/4062], Loss: 0.0103
# Epoch [5/5], Batch [3110/4062], Loss: 0.0001
# Epoch [5/5], Batch [3120/4062], Loss: 0.0076
# Epoch [5/5], Batch [3130/4062], Loss: 0.0000
# Epoch [5/5], Batch [3140/4062], Loss: 0.0010
# Epoch [5/5], Batch [3150/4062], Loss: 0.0005
# Epoch [5/5], Batch [3160/4062], Loss: 0.0059
# Epoch [5/5], Batch [3170/4062], Loss: 0.0001
# Epoch [5/5], Batch [3180/4062], Loss: 0.0003
# Epoch [5/5], Batch [3190/4062], Loss: 0.0073
# Epoch [5/5], Batch [3200/4062], Loss: 0.0001
# Epoch [5/5], Batch [3210/4062], Loss: 0.0002
# Epoch [5/5], Batch [3220/4062], Loss: 0.0022
# Epoch [5/5], Batch [3230/4062], Loss: 0.0001
# Epoch [5/5], Batch [3240/4062], Loss: 0.0015
# Epoch [5/5], Batch [3250/4062], Loss: 0.0001
# Epoch [5/5], Batch [3260/4062], Loss: 0.0003
# Epoch [5/5], Batch [3270/4062], Loss: 0.0035
# Epoch [5/5], Batch [3280/4062], Loss: 0.0002
# Epoch [5/5], Batch [3290/4062], Loss: 0.0011
# Epoch [5/5], Batch [3300/4062], Loss: 0.0002
# Epoch [5/5], Batch [3310/4062], Loss: 0.0001
# Epoch [5/5], Batch [3320/4062], Loss: 0.0004
# Epoch [5/5], Batch [3330/4062], Loss: 0.0023
# Epoch [5/5], Batch [3340/4062], Loss: 0.0009
# Epoch [5/5], Batch [3350/4062], Loss: 0.0010
# Epoch [5/5], Batch [3360/4062], Loss: 0.0001
# Epoch [5/5], Batch [3370/4062], Loss: 0.0002
# Epoch [5/5], Batch [3380/4062], Loss: 0.0001
# Epoch [5/5], Batch [3390/4062], Loss: 0.0148
# Epoch [5/5], Batch [3400/4062], Loss: 0.0004
# Epoch [5/5], Batch [3410/4062], Loss: 0.0003
# Epoch [5/5], Batch [3420/4062], Loss: 0.0002
# Epoch [5/5], Batch [3430/4062], Loss: 0.0003
# Epoch [5/5], Batch [3440/4062], Loss: 0.0037
# Epoch [5/5], Batch [3450/4062], Loss: 0.0000
# Epoch [5/5], Batch [3460/4062], Loss: 0.0171
# Epoch [5/5], Batch [3470/4062], Loss: 0.0010
# Epoch [5/5], Batch [3480/4062], Loss: 0.0002
# Epoch [5/5], Batch [3490/4062], Loss: 0.0112
# Epoch [5/5], Batch [3500/4062], Loss: 0.0000
# Epoch [5/5], Batch [3510/4062], Loss: 0.0001
# Epoch [5/5], Batch [3520/4062], Loss: 0.0010
# Epoch [5/5], Batch [3530/4062], Loss: 0.0001
# Epoch [5/5], Batch [3540/4062], Loss: 0.0042
# Epoch [5/5], Batch [3550/4062], Loss: 0.0003
# Epoch [5/5], Batch [3560/4062], Loss: 0.0014
# Epoch [5/5], Batch [3570/4062], Loss: 0.0001
# Epoch [5/5], Batch [3580/4062], Loss: 0.0050
# Epoch [5/5], Batch [3590/4062], Loss: 0.0000
# Epoch [5/5], Batch [3600/4062], Loss: 0.0003
# Epoch [5/5], Batch [3610/4062], Loss: 0.0111
# Epoch [5/5], Batch [3620/4062], Loss: 0.0002
# Epoch [5/5], Batch [3630/4062], Loss: 0.0021
# Epoch [5/5], Batch [3640/4062], Loss: 0.0009
# Epoch [5/5], Batch [3650/4062], Loss: 0.0001
# Epoch [5/5], Batch [3660/4062], Loss: 0.0091
# Epoch [5/5], Batch [3670/4062], Loss: 0.0006
# Epoch [5/5], Batch [3680/4062], Loss: 0.0003
# Epoch [5/5], Batch [3690/4062], Loss: 0.0001
# Epoch [5/5], Batch [3700/4062], Loss: 0.0010
# Epoch [5/5], Batch [3710/4062], Loss: 0.0001
# Epoch [5/5], Batch [3720/4062], Loss: 0.0005
# Epoch [5/5], Batch [3730/4062], Loss: 0.0005
# Epoch [5/5], Batch [3740/4062], Loss: 0.0000
# Epoch [5/5], Batch [3750/4062], Loss: 0.0021
# Epoch [5/5], Batch [3760/4062], Loss: 0.0039
# Epoch [5/5], Batch [3770/4062], Loss: 0.0014
# Epoch [5/5], Batch [3780/4062], Loss: 0.0042
# Epoch [5/5], Batch [3790/4062], Loss: 0.0000
# Epoch [5/5], Batch [3800/4062], Loss: 0.0021
# Epoch [5/5], Batch [3810/4062], Loss: 0.0001
# Epoch [5/5], Batch [3820/4062], Loss: 0.0014
# Epoch [5/5], Batch [3830/4062], Loss: 0.0002
# Epoch [5/5], Batch [3840/4062], Loss: 0.0004
# Epoch [5/5], Batch [3850/4062], Loss: 0.0002
# Epoch [5/5], Batch [3860/4062], Loss: 0.0001
# Epoch [5/5], Batch [3870/4062], Loss: 0.0006
# Epoch [5/5], Batch [3880/4062], Loss: 0.0009
# Epoch [5/5], Batch [3890/4062], Loss: 0.0003
# Epoch [5/5], Batch [3900/4062], Loss: 0.0004
# Epoch [5/5], Batch [3910/4062], Loss: 0.0007
# Epoch [5/5], Batch [3920/4062], Loss: 0.0000
# Epoch [5/5], Batch [3930/4062], Loss: 0.0043
# Epoch [5/5], Batch [3940/4062], Loss: 0.0070
# Epoch [5/5], Batch [3950/4062], Loss: 0.0007
# Epoch [5/5], Batch [3960/4062], Loss: 0.0025
# Epoch [5/5], Batch [3970/4062], Loss: 0.0001
# Epoch [5/5], Batch [3980/4062], Loss: 0.0006
# Epoch [5/5], Batch [3990/4062], Loss: 0.0003
# Epoch [5/5], Batch [4000/4062], Loss: 0.0000
# Epoch [5/5], Batch [4010/4062], Loss: 0.0180
# Epoch [5/5], Batch [4020/4062], Loss: 0.0000
# Epoch [5/5], Batch [4030/4062], Loss: 0.0000
# Epoch [5/5], Batch [4040/4062], Loss: 0.0041
# Epoch [5/5], Batch [4050/4062], Loss: 0.0008
# Epoch [5/5], Batch [4060/4062], Loss: 0.0003
# Epoch 5/5, Loss: 0.002421416560310032
# Updated Learning Rate: [4.993273615984001e-06]
#               precision    recall  f1-score   support
#
#    overdrive       1.00      1.00      1.00      3012
#   distortion       1.00      1.00      1.00      4518
#         fuzz       1.00      1.00      1.00      5271
#      tremolo       1.00      1.00      1.00      3765
#       phaser       1.00      1.00      1.00      4518
#      flanger       0.99      1.00      1.00      3012
#       chorus       1.00      1.00      1.00      5271
#        delay       0.99      0.99      0.99      6777
#  hall_reverb       0.97      0.99      0.98      4518
# plate_reverb       0.99      0.99      0.99      3012
#      octaver       1.00      1.00      1.00      2259
#  auto_filter       1.00      1.00      1.00      3765
#
#    micro avg       0.99      1.00      1.00     49698
#    macro avg       0.99      1.00      1.00     49698
# weighted avg       0.99      1.00      1.00     49698
#  samples avg       0.97      0.97      0.97     49698
#
#
# Validation Loss: 0.0045, Accuracy: 0.9855, Precision: 0.9949, Recall: 0.9965, F1-score: 0.9957
#
# Model saved to /content/drive/MyDrive/W210/Models/last_model.mod
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

test_dataset = SpectrogramDataset(h5_test_path, csv_test_path)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=12, pin_memory=True)

num_classes = len(test_dataset.label_map)

# Load a saved model for test dataset metrics
model = spectrogramCNN(num_classes).to(device)
model.load_state_dict(torch.load(model_load_path, map_location=device))
model.eval()
print("Model loaded successfully.")

print("\nEvaluating with external test dataset...")

model.eval()
criterion = nn.BCEWithLogitsLoss()
test_loss = 0.0
test_preds, test_labels = [], []

with torch.no_grad():
    for spectrograms, labels in test_loader:
        spectrograms, labels = spectrograms.to(device), labels.to(device)
        outputs = model(spectrograms)
        loss = criterion(outputs, labels)
        test_loss += loss.item()

        # Convert logits to binary predictions
        predicted = (torch.sigmoid(outputs) > 0.5).float()

        test_preds.extend(predicted.cpu().numpy())
        test_labels.extend(labels.cpu().numpy())

test_loss /= len(test_loader)

# Compute test metrics
test_preds = np.array(test_preds)
test_labels = np.array(test_labels)
test_accuracy = accuracy_score(test_labels, test_preds)
test_precision = precision_score(test_labels, test_preds, average="macro", zero_division=0)
test_recall = recall_score(test_labels, test_preds, average="macro", zero_division=0)
test_f1 = f1_score(test_labels, test_preds, average="macro", zero_division=0)

print(f"\nTest Loss: {test_loss:.4f}, Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}, F1-score: {test_f1:.4f}\n")

# Print classification report
class_names = test_dataset.label_map
print(classification_report(test_labels, test_preds, target_names=class_names))
# Out:
# <ipython-input-9-4c61356b6bb0>:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_load_path, map_location=device))
# Model loaded successfully.
#
# Evaluating with external test dataset...
#
# Test Loss: 0.0055, Accuracy: 0.9860, Precision: 0.9954, Recall: 0.9940, F1-score: 0.9947
#
#               precision    recall  f1-score   support
#
#    overdrive       1.00      0.99      1.00      3028
#   distortion       1.00      1.00      1.00      4544
#         fuzz       1.00      1.00      1.00      5300
#      tremolo       1.00      1.00      1.00      3028
#       phaser       1.00      1.00      1.00      4542
#      flanger       1.00      0.99      0.99      3028
#       chorus       1.00      1.00      1.00      5300
#        delay       1.00      0.99      1.00      6814
#  hall_reverb       0.97      0.99      0.98      3788
# plate_reverb       0.99      0.99      0.99      3028
#      octaver       0.99      0.99      0.99      2271
#  auto_filter       1.00      0.99      1.00      3785
#
#    micro avg       1.00      0.99      1.00     48456
#    macro avg       1.00      0.99      0.99     48456
# weighted avg       1.00      0.99      1.00     48456
#  samples avg       0.97      0.97      0.97     48456
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

real_dataset = SpectrogramDataset(h5_real_path, csv_real_path)
real_loader = DataLoader(real_dataset, batch_size=32, shuffle=False, num_workers=12, pin_memory=True)

num_classes = len(real_dataset.label_map)

# Load a saved model for real dataset metrics
model = spectrogramCNN(num_classes).to(device)
model.load_state_dict(torch.load(model_load_path, map_location=device))
model.eval()
print("Model loaded successfully.")

print("\nEvaluating with external real dataset...")

model.eval()
criterion = nn.BCEWithLogitsLoss()
real_loss = 0.0
real_preds, real_labels = [], []

with torch.no_grad():
    for spectrograms, labels in real_loader:
        spectrograms, labels = spectrograms.to(device), labels.to(device)
        outputs = model(spectrograms)
        loss = criterion(outputs, labels)
        real_loss += loss.item()

        # Convert logits to binary predictions
        predicted = (torch.sigmoid(outputs) > 0.5).float()

        real_preds.extend(predicted.cpu().numpy())
        real_labels.extend(labels.cpu().numpy())

real_loss /= len(real_loader)

# Compute real metrics
real_preds = np.array(real_preds)
real_labels = np.array(real_labels)
real_accuracy = accuracy_score(real_labels, real_preds)
real_precision = precision_score(real_labels, real_preds, average="macro", zero_division=0)
real_recall = recall_score(real_labels, real_preds, average="macro", zero_division=0)
real_f1 = f1_score(real_labels, real_preds, average="macro", zero_division=0)

print(f"\nreal Loss: {real_loss:.4f}, Accuracy: {real_accuracy:.4f}, Precision: {real_precision:.4f}, Recall: {real_recall:.4f}, F1-score: {real_f1:.4f}\n")

# Print classification report
class_names = real_dataset.label_map
print(classification_report(real_labels, real_preds, target_names=class_names))
# Out:
# Model loaded successfully.
#
# Evaluating with external real dataset...
# <ipython-input-10-5f0761d28777>:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_load_path, map_location=device))
# real Loss: 0.0907, Accuracy: 0.8254, Precision: 0.9089, Recall: 0.9338, F1-score: 0.9166
#
#               precision    recall  f1-score   support
#
#    overdrive       0.86      0.83      0.84      3432
#   distortion       0.97      0.97      0.97      5148
#         fuzz       0.98      0.98      0.98      6006
#      tremolo       0.89      0.99      0.94      4290
#       phaser       0.99      0.97      0.98      5148
#      flanger       0.95      0.74      0.83      3432
#       chorus       0.94      0.95      0.94      6006
#        delay       0.98      0.94      0.96      7722
#  hall_reverb       0.92      0.97      0.95      5148
# plate_reverb       0.97      0.93      0.95      3432
#      octaver       0.66      0.97      0.79      2574
#  auto_filter       0.79      0.97      0.87      4290
#
#    micro avg       0.92      0.94      0.93     56628
#    macro avg       0.91      0.93      0.92     56628
# weighted avg       0.93      0.94      0.93     56628
#  samples avg       0.89      0.90      0.89     56628
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import combinations
from collections import defaultdict

def format_label_combination(combination):
    if len(combination) == 0:
        return "Clean"
    elif len(combination) == 1:
        return combination[0]
    else:
        return " and ".join(combination)

def create_multilabel_confusion_matrix(y_true, y_pred, class_names):
    combinations = defaultdict(lambda: defaultdict(int))
    for true_labels, pred_labels in zip(y_true, y_pred):
        true_label_names = tuple(sorted([class_names[i] for i in np.where(true_labels == 1)[0]]))
        pred_label_names = tuple(sorted([class_names[i] for i in np.where(pred_labels == 1)[0]]))
        true_label_names = format_label_combination(true_label_names)
        pred_label_names = format_label_combination(pred_label_names)

        combinations[true_label_names][pred_label_names] += 1
    df = pd.DataFrame.from_dict(combinations, orient='index').fillna(0)
    df = df.reindex(sorted(df.columns), axis=1)
    df = df.reindex(sorted(df.index), axis=0)
    return df

multi_label_cm = create_multilabel_confusion_matrix(real_labels, real_preds, class_names)

plt.figure(figsize=(60, 20))
sns.heatmap(multi_label_cm, annot=True, fmt=".0f", cmap="Blues", linewidths=0.5, linecolor="gray")
plt.xlabel("Predicted Label Combinations")
plt.ylabel("True Label Combinations")
plt.title("Multi-label Confusion Matrix (Observed Label Combinations)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f9b2c236ac32> in <cell line: 0>()
#      27     return df
#      28
# ---> 29 multi_label_cm = create_multilabel_confusion_matrix(real_labels, real_preds, class_names)
#      30
#      31 plt.figure(figsize=(60, 20))
#
# NameError: name 'real_labels' is not defined

# %%
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import combinations
from collections import defaultdict

def create_multilabel_confusion_matrix(y_true, y_pred, class_names):
    combinations = defaultdict(lambda: defaultdict(int))
    for true_labels, pred_labels in zip(y_true, y_pred):
        for x, true_label in enumerate(true_labels):
            for y, pred_label in enumerate(pred_labels):
                if true_label == 1 and pred_label == 1:
                    true_label_name = class_names[x]
                    pred_label_name = class_names[y]
                    combinations[true_label_name][pred_label_name] += 1
    df = pd.DataFrame.from_dict(combinations, orient='index').fillna(0)
    df = df.reindex(sorted(df.columns), axis=1)
    df = df.reindex(sorted(df.index), axis=0)
    return df

multi_label_cm = create_multilabel_confusion_matrix(real_labels, real_preds, class_names)

plt.figure(figsize=(15, 10))
sns.heatmap(multi_label_cm, annot=True, fmt=".0f", cmap="Blues")
plt.xlabel("Predicted Label Combinations")
plt.ylabel("True Label Combinations")
plt.title("Multi-label Confusion Matrix")
plt.show()

# %%
confusion_matrix = multilabel_confusion_matrix(real_labels, real_preds, labels=[i for i in range(len(class_names))])

for i, cm in enumerate(confusion_matrix):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt=".0f", cmap="Blues", xticklabels=["Predicted Negative", "Predicted Positive"], yticklabels=["Actual Negative", "Actual Positive"])
    plt.title(f"Confusion Matrix for {class_names[i]}")
    plt.show()
